# %%
# Indexing

# %%
# Import

import pandas as pd

# Creating an index on country

df = pd.read_csv(r"C:\Users\ewlem\Documents\Portfolio Projects\Python\Pandas\world_population.csv", index_col = "Country")
pd.set_option("display.max.rows", 235)

# %%
df
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
# Resetting index
df.reset_index(inplace=True)
df
# Out:
#          Continent  level_0  index                           Country  Rank  \
# 0             Asia        0      0                       Afghanistan    36
# 1           Europe        1      1                           Albania   138
# 2           Africa        2      2                           Algeria    34
# 3          Oceania        3      3                    American Samoa   213
# 4           Europe        4      4                           Andorra   203
# 5           Africa        5      5                            Angola    42
# 6    North America        6      6                          Anguilla   224
# 7    North America        7      7               Antigua and Barbuda   201
# 8    South America        8      8                         Argentina    33
# 9             Asia        9      9                           Armenia   140
# 10   North America       10     10                             Aruba   198
# ...

# %%
df.set_index("Continent", inplace = True)

# %%
df
# Out:
#                level_0  index                           Country  Rank CCA3  \
# Continent
# Asia                 0      0                       Afghanistan    36  AFG
# Europe               1      1                           Albania   138  ALB
# Africa               2      2                           Algeria    34  DZA
# Oceania              3      3                    American Samoa   213  ASM
# Europe               4      4                           Andorra   203  AND
# Africa               5      5                            Angola    42  AGO
# North America        6      6                          Anguilla   224  AIA
# North America        7      7               Antigua and Barbuda   201  ATG
# South America        8      8                         Argentina    33  ARG
# Asia                 9      9                           Armenia   140  ARM
# North America       10     10                             Aruba   198  ABW
# ...

# %%
df.loc["Europe"]
# Out:
#            level_0  index                 Country  Rank CCA3  \
# Continent
# Europe           1      1                 Albania   138  ALB
# Europe           4      4                 Andorra   203  AND
# Europe          12     12                 Austria    99  AUT
# Europe          18     18                 Belarus    96  BLR
# Europe          19     19                 Belgium    81  BEL
# Europe          25     25  Bosnia and Herzegovina   137  BIH
# Europe          30     30                Bulgaria   108  BGR
# Europe          46     46                 Croatia   130  HRV
# Europe          49     49                  Cyprus   158  CYP
# Europe          50     50          Czech Republic    88  CZE
# Europe          51     51                 Denmark   115  DNK
# Europe          61     61                 Estonia   156  EST
# Europe          65     65           Faroe Islands   209  FRO
# Europe          67     67                 Finland   118  FIN
# ...

# %%
df.reset_index(inplace=True)

# %%
df.set_index(["Continent","Rank"], inplace=True)

# %%
df.sort_index()
# Out:
#                                              Country  level_0  index CCA3  \
# Continent     Rank
# Africa        6                              Nigeria      149    149  NGA
#               12                            Ethiopia       63     63  ETH
#               14                               Egypt       57     57  EGY
#               15                            DR Congo       55     55  COD
#               22                            Tanzania      205    205  TZA
#               24                        South Africa      193    193  ZAF
#               27                               Kenya      106    106  KEN
#               31                              Uganda      217    217  UGA
#               32                               Sudan      198    198  SDN
#               34                             Algeria        2      2  DZA
#               40                             Morocco      138    138  MAR
# ...

# %%
# df.loc won't work on specific countries since continent is the main index so...

df.loc["Africa", 22]
# Out:
# Country                          Tanzania
# level_0                               205
# index                                 205
# CCA3                                  TZA
# Capital                            Dodoma
# 2022 Population                65497748.0
# 2020 Population                61704518.0
# 2015 Population                52542823.0
# 2010 Population                45110527.0
# 2000 Population                34463704.0
# 1990 Population                26206012.0
# 1980 Population                19297659.0
# 1970 Population                13618192.0
# Area (km²)                       945087.0
# Density (per km²)                 69.3034
# Growth Rate                          1.03
# World Population Percentage          0.82
# Name: (Africa, 22), dtype: object

# %%
# df.iloc will only go on the original index numbers set to each row

df.iloc[22]
# Out:
# Country                          Bermuda
# level_0                               22
# index                                 22
# CCA3                                 BMU
# Capital                         Hamilton
# 2022 Population                  64184.0
# 2020 Population                  64031.0
# 2015 Population                  63144.0
# 2010 Population                  63447.0
# 2000 Population                  61371.0
# 1990 Population                  57470.0
# 1980 Population                  53565.0
# 1970 Population                  52019.0
# Area (km²)                          54.0
# Density (per km²)              1188.5926
# Growth Rate                          1.0
# World Population Percentage          0.0
# Name: (North America, 206), dtype: object
